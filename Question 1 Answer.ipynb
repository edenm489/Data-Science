# %%
get_ipython().run_line_magic('matplotlib', 'inline')
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import seaborn as sns

# %%
data = pd.read_excel('2019 Winter Data Science Intern Challenge Data Set.xlsx')

# %%
data.columns
# Out:
# Index(['order_id', 'shop_id', 'user_id', 'order_amount', 'total_items',
#        'payment_method', 'created_at'],
#       dtype='object')

# %%
data.order_amount.describe()
# Out:
# count      5000.000000
# mean       3145.128000
# std       41282.539349
# min          90.000000
# 25%         163.000000
# 50%         284.000000
# 75%         390.000000
# max      704000.000000
# Name: order_amount, dtype: float64

# %%
# Scatter plot to determine data distribution
fig = plt.figure(figsize=(7,4))
cg = sns.scatterplot(y="order_amount", x = "order_id", data=data)

# %%
# Determining the values that are out of bound and how many times
upper = data.groupby(['order_amount']).size().reset_index(name='total').sort_values(by='order_amount', ascending=False)
upper.head(15)
# Out:
#      order_amount  total
# 257        704000     17
# 256        154350      1
# 255        102900      1
# 254         77175      9
# 253         51450     16
# 252         25725     19
# 251          1760      1
# 250          1408      2
# 249          1086      1
# 248          1064      1
# 247          1056      3
# 246           980      1
# 245           965      1
# 244           960      2
# 243           948      1

# %%
#Based on the data above, the order_amount that is larger than 1760 seem to be outliers. 
#Now analysing the data for order_amount of 704000
data.loc[data['order_amount'].isin([704000])].sort_values(by='order_amount', ascending=False)
# Out:
#       order_id  shop_id  user_id  order_amount  total_items payment_method  \
# 15          16       42      607        704000         2000    credit_card
# 2297      2298       42      607        704000         2000    credit_card
# 4868      4869       42      607        704000         2000    credit_card
# 4646      4647       42      607        704000         2000    credit_card
# 4056      4057       42      607        704000         2000    credit_card
# 3332      3333       42      607        704000         2000    credit_card
# 2969      2970       42      607        704000         2000    credit_card
# 2835      2836       42      607        704000         2000    credit_card
# 2153      2154       42      607        704000         2000    credit_card
# 60          61       42      607        704000         2000    credit_card
# 1602      1603       42      607        704000         2000    credit_card
# ...

# %%
#Based on the data, analysing the data for order_amount of 77175
data.loc[data['order_amount'].isin([77175])].sort_values(by='order_amount', ascending=False)
# Out:
#       order_id  shop_id  user_id  order_amount  total_items payment_method  \
# 1259      1260       78      775         77175            3    credit_card
# 2564      2565       78      915         77175            3          debit
# 2690      2691       78      962         77175            3          debit
# 2906      2907       78      817         77175            3          debit
# 3403      3404       78      928         77175            3          debit
# 3724      3725       78      766         77175            3    credit_card
# 4192      4193       78      787         77175            3    credit_card
# 4420      4421       78      969         77175            3          debit
# 4715      4716       78      818         77175            3          debit
#
#                   created_at
# 1259 2017-03-27 09:27:19.843
# 2564 2017-03-25 01:19:35.410
# 2690 2017-03-22 07:33:25.104
# 2906 2017-03-16 03:45:46.089
# 3403 2017-03-16 09:45:04.544
# 3724 2017-03-16 14:13:25.868
# ...

# %%
#Based on the data, analysing the data for order_amount of 51450
data.loc[data['order_amount'].isin([51450])].sort_values(by='order_amount', ascending=False)
# Out:
#       order_id  shop_id  user_id  order_amount  total_items payment_method  \
# 490        491       78      936         51450            2          debit
# 493        494       78      983         51450            2           cash
# 511        512       78      967         51450            2           cash
# 617        618       78      760         51450            2           cash
# 1529      1530       78      810         51450            2           cash
# 2452      2453       78      709         51450            2           cash
# 2495      2496       78      707         51450            2           cash
# 2512      2513       78      935         51450            2          debit
# 2818      2819       78      869         51450            2          debit
# 2821      2822       78      814         51450            2           cash
# 3101      3102       78      855         51450            2    credit_card
# ...

# %%
#Based on the data, analysing the data for order_amount of 25725
data.loc[data['order_amount'].isin([25725])].sort_values(by='order_amount', ascending=False)
# Out:
#       order_id  shop_id  user_id  order_amount  total_items payment_method  \
# 160        161       78      990         25725            1    credit_card
# 2922      2923       78      740         25725            1          debit
# 4584      4585       78      997         25725            1           cash
# 4505      4506       78      866         25725            1          debit
# 4040      4041       78      852         25725            1           cash
# 3780      3781       78      889         25725            1           cash
# 3440      3441       78      982         25725            1          debit
# 3151      3152       78      745         25725            1    credit_card
# 3085      3086       78      910         25725            1           cash
# 2773      2774       78      890         25725            1           cash
# 1056      1057       78      800         25725            1          debit
# ...

# %%
data.boxplot("order_amount")
# Out:
# <AxesSubplot:>

# %%
for x in ['order_amount']:
    upper75,lower25 = np.percentile(data.loc[:,x],[75,25])
    intr_qr = upper75-lower25
 
    max = upper75+1.5*intr_qr
    min = lower25-1.5*intr_qr
 
    data.loc[data[x] < min,x] = np.nan
    data.loc[data[x] > max,x] = np.nan

data = data.dropna(axis = 0)
data.boxplot("order_amount")
# Out:
# <AxesSubplot:>

# %%
data.isnull().sum()
# Out:
# order_id          0
# shop_id           0
# user_id           0
# order_amount      0
# total_items       0
# payment_method    0
# created_at        0
# dtype: int64

# %%
data.order_amount.describe()
# Out:
# count    4859.000000
# mean      293.715374
# std       144.453395
# min        90.000000
# 25%       162.000000
# 50%       280.000000
# 75%       380.000000
# max       730.000000
# Name: order_amount, dtype: float64
